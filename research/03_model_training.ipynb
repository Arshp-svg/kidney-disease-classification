# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\ARSH\\Desktop\\MLOps\\kidney-disease-classification'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class TrainingConfig:
   root_dir: Path
   model_checkpoint: Path
   updated_base_model_path:Path
   training_data:Path
   params_epoch:int
   params_batch_size:int
   params_image_size:list
   params_augmentation:bool

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH,PARAMS_FILE_PATH
from cnnClassifier.utils.common import read_yaml,create_directories
import tensorflow as tf

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath=CONFIG_FILE_PATH, 
        params_filepath=PARAMS_FILE_PATH):
        
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        
        
        create_directories([self.config.artifacts_root])
        
        
    def get_training_config(self) -> TrainingConfig:
        training=self.config.training
        prepare_base_model=self.config.prepare_base_model
        
        params=self.params
        training_data=os.path.join(self.config.data_ingestion.unzip_dir,"kidney-ct-scan-image")
        
        create_directories([training.root_dir])
        
        training_config = TrainingConfig(
            root_dir=training.root_dir,
            model_checkpoint=training.model_checkpoint,
            updated_base_model_path=prepare_base_model.updated_base_model_path,
            training_data=training_data,
            params_epoch=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_image_size=params.IMAGE_SIZE,
            params_augmentation=params.AUGMENTATION
        )

        return training_config

# %%
import os
from zipfile import ZipFile
import urllib.request as request
import tensorflow as tf
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config

    def get_base_model(self):
        self.model = tf.keras.models.load_model(self.config.updated_base_model_path)
    
    
    def train_valid_generator(self):

        ## data generator copied from keras documentation
        datagenerator_kwargs=dict(
            rescale=1./255,
            validation_split=0.2
        )

        dataflow_kwargs=dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )
    

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator=valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )
        
        if self.config.params_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                **datagenerator_kwargs,
                rotation_range=40,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
            )
            
        else:
            train_datagenerator=valid_datagenerator
            
        self.train_generator=train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )
        
    @staticmethod
    def save_model(path:Path, model:tf.keras.Model):
        model.save(path)


    def train(self):
        # formula used for calculating steps per epoch and validation steps
        self.steps_per_epochs = self.train_generator.samples // self.config.params_batch_size
        self.validation_steps = self.valid_generator.samples // self.config.params_batch_size
        
        self.model.fit(
            self.train_generator,
            validation_data=self.valid_generator,
            epochs=self.config.params_epoch,
            steps_per_epoch=self.steps_per_epochs,
            validation_steps=self.validation_steps
        )

        self.save_model(path=self.config.model_checkpoint, model=self.model)

# %%
try:
    config=ConfigurationManager()
    training_config=config.get_training_config()
    training=Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train()
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# YAML content loaded: {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/data_ingestion', 'source_url': 'https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharin', 'local_file': 'artifacts/data_ingestion/data.zip', 'unzip_dir': 'artifacts/data_ingestion'}, 'prepare_base_model': {'root_dir': 'artifacts/prepare_base_model', 'base_model_path': 'artifacts/prepare_base_model/base_model.h5', 'updated_base_model_path': 'artifacts/prepare_base_model/updated_model.h5'}, 'training': {'root_dir': 'artifacts/training', 'model_checkpoint': 'artifacts/training/model.h5'}}
# YAML content loaded: {'AUGMENTATION': True, 'IMAGE_SIZE': [224, 224, 3], 'BATCH_SIZE': 32, 'INCLUDE_TOP': False, 'CLASSES': 2, 'WEIGHTS': 'imagenet', 'EPOCHS': 200, 'LEARNING_RATE': 0.01}
# [2025-08-19 20:22:14,035] INFO in common: Created directory: artifacts
# [2025-08-19 20:22:14,036] INFO in common: Created directory: artifacts/training
# Found 93 images belonging to 2 classes.
# Found 372 images belonging to 2 classes.
# Epoch 1/200
# 11/11 [==============================] - 32s 3s/step - loss: 5.7088 - accuracy: 0.7794 - val_loss: 4.3475 - val_accuracy: 0.7500
# Epoch 2/200
# 11/11 [==============================] - 49s 4s/step - loss: 5.1210 - accuracy: 0.7824 - val_loss: 0.1224 - val_accuracy: 0.9844
# Epoch 3/200
# 11/11 [==============================] - 31s 3s/step - loss: 1.3319 - accuracy: 0.9029 - val_loss: 1.7627e-04 - val_accuracy: 1.0000
# Epoch 4/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.8250 - accuracy: 0.9235 - val_loss: 7.7917e-05 - val_accuracy: 1.0000
# Epoch 5/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.2120 - accuracy: 0.9735 - val_loss: 0.0251 - val_accuracy: 0.9844
# Epoch 6/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.1031 - accuracy: 0.9853 - val_loss: 3.9116e-08 - val_accuracy: 1.0000
# Epoch 7/200
# 11/11 [==============================] - 59s 6s/step - loss: 0.0799 - accuracy: 0.9912 - val_loss: 2.2648e-06 - val_accuracy: 1.0000
# Epoch 8/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.1032 - accuracy: 0.9824 - val_loss: 2.6653e-04 - val_accuracy: 1.0000
# Epoch 9/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0895 - accuracy: 0.9912 - val_loss: 3.3528e-08 - val_accuracy: 1.0000
# Epoch 10/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.4860 - accuracy: 0.9471 - val_loss: 0.0773 - val_accuracy: 0.9688
# Epoch 11/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1291 - accuracy: 0.9824 - val_loss: 1.0408e-04 - val_accuracy: 1.0000
# Epoch 12/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1414 - accuracy: 0.9824 - val_loss: 8.1956e-08 - val_accuracy: 1.0000
# Epoch 13/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.0438 - accuracy: 0.9853 - val_loss: 0.1198 - val_accuracy: 0.9688
# Epoch 14/200
# 11/11 [==============================] - 37s 3s/step - loss: 0.1379 - accuracy: 0.9882 - val_loss: 0.2576 - val_accuracy: 0.9531
# Epoch 15/200
# 11/11 [==============================] - 58s 5s/step - loss: 1.9292e-05 - accuracy: 1.0000 - val_loss: 5.1545e-05 - val_accuracy: 1.0000
# Epoch 16/200
# 11/11 [==============================] - 35s 3s/step - loss: 0.0444 - accuracy: 0.9941 - val_loss: 0.2123 - val_accuracy: 0.9688
# Epoch 17/200
# 11/11 [==============================] - 74s 7s/step - loss: 0.0380 - accuracy: 0.9912 - val_loss: 5.5879e-09 - val_accuracy: 1.0000
# Epoch 18/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0323 - accuracy: 0.9941 - val_loss: 0.0381 - val_accuracy: 0.9844
# Epoch 19/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0539 - accuracy: 0.9941 - val_loss: 3.2969e-07 - val_accuracy: 1.0000
# Epoch 20/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0685 - val_accuracy: 0.9688
# Epoch 21/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0325 - accuracy: 0.9972 - val_loss: 2.8608e-06 - val_accuracy: 1.0000
# Epoch 22/200
# 11/11 [==============================] - 47s 4s/step - loss: 0.0304 - accuracy: 0.9972 - val_loss: 0.0157 - val_accuracy: 0.9844
# Epoch 23/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0473 - accuracy: 0.9941 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 24/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 5.5309e-05 - val_accuracy: 1.0000
# Epoch 25/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0167 - accuracy: 0.9971 - val_loss: 2.0489e-08 - val_accuracy: 1.0000
# Epoch 26/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0207 - accuracy: 0.9971 - val_loss: 1.3299e-06 - val_accuracy: 1.0000
# Epoch 27/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0875 - accuracy: 0.9858 - val_loss: 5.7888e-06 - val_accuracy: 1.0000
# Epoch 28/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0147 - accuracy: 0.9941 - val_loss: 1.3627e-04 - val_accuracy: 1.0000
# Epoch 29/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0548 - accuracy: 0.9912 - val_loss: 3.2969e-07 - val_accuracy: 1.0000
# Epoch 30/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0646 - accuracy: 0.9912 - val_loss: 4.4703e-08 - val_accuracy: 1.0000
# Epoch 31/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0045 - accuracy: 0.9971 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 32/200
# 11/11 [==============================] - 35s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.4135e-05 - val_accuracy: 1.0000
# Epoch 33/200
# 11/11 [==============================] - 44s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.5320e-05 - val_accuracy: 1.0000
# Epoch 34/200
# 11/11 [==============================] - 63s 6s/step - loss: 0.0525 - accuracy: 0.9912 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 35/200
# 11/11 [==============================] - 130s 12s/step - loss: 0.0361 - accuracy: 0.9941 - val_loss: 0.0308 - val_accuracy: 0.9844
# Epoch 36/200
# 11/11 [==============================] - 122s 12s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.2670e-06 - val_accuracy: 1.0000
# Epoch 37/200
# 11/11 [==============================] - 29s 3s/step - loss: 0.1148 - accuracy: 0.9971 - val_loss: 4.8987e-07 - val_accuracy: 1.0000
# Epoch 38/200
# 11/11 [==============================] - 37s 3s/step - loss: 0.0271 - accuracy: 0.9943 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/200
# 11/11 [==============================] - 45s 4s/step - loss: 0.0292 - accuracy: 0.9941 - val_loss: 1.0501 - val_accuracy: 0.8125
# Epoch 40/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0771 - accuracy: 0.9882 - val_loss: 3.5390e-08 - val_accuracy: 1.0000
# Epoch 41/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0514 - accuracy: 0.9912 - val_loss: 0.0384 - val_accuracy: 0.9844
# Epoch 42/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.4060 - accuracy: 0.9347 - val_loss: 0.1388 - val_accuracy: 0.9688
# Epoch 43/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0471 - accuracy: 0.9912 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 44/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1576 - accuracy: 0.9882 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 45/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0339 - accuracy: 0.9971 - val_loss: 8.1582e-07 - val_accuracy: 1.0000
# Epoch 46/200
# 11/11 [==============================] - 33s 3s/step - loss: 1.8477e-06 - accuracy: 1.0000 - val_loss: 3.6932e-06 - val_accuracy: 1.0000
# Epoch 47/200
# 11/11 [==============================] - 34s 3s/step - loss: 7.9426e-06 - accuracy: 1.0000 - val_loss: 6.1530e-06 - val_accuracy: 1.0000
# Epoch 48/200
# 11/11 [==============================] - 44s 4s/step - loss: 6.0793e-07 - accuracy: 1.0000 - val_loss: 7.6015e-06 - val_accuracy: 1.0000
# Epoch 49/200
# 11/11 [==============================] - 35s 3s/step - loss: 5.2904e-07 - accuracy: 1.0000 - val_loss: 8.1470e-06 - val_accuracy: 1.0000
# Epoch 50/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0167 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 51/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.0406 - accuracy: 0.9941 - val_loss: 2.3414 - val_accuracy: 0.7656
# Epoch 52/200
# 11/11 [==============================] - 41s 4s/step - loss: 0.1266 - accuracy: 0.9912 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 53/200
# 11/11 [==============================] - 68s 6s/step - loss: 0.0150 - accuracy: 0.9971 - val_loss: 5.6489e-06 - val_accuracy: 1.0000
# Epoch 54/200
# 11/11 [==============================] - 63s 6s/step - loss: 1.7425e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 55/200
# 11/11 [==============================] - 41s 3s/step - loss: 1.1395e-07 - accuracy: 1.0000 - val_loss: 4.6566e-08 - val_accuracy: 1.0000
# Epoch 56/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 57/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0048 - accuracy: 0.9971 - val_loss: 3.4100e-04 - val_accuracy: 1.0000
# Epoch 58/200
# 11/11 [==============================] - 29s 3s/step - loss: 0.0039 - accuracy: 0.9971 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 59/200
# 11/11 [==============================] - 30s 3s/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 60/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0243 - accuracy: 0.9971 - val_loss: 0.1051 - val_accuracy: 0.9688
# Epoch 61/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0240 - accuracy: 0.9971 - val_loss: 1.2107e-07 - val_accuracy: 1.0000
# Epoch 62/200
# 11/11 [==============================] - 31s 3s/step - loss: 1.7531e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 63/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0050 - accuracy: 0.9971 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 64/200
# 11/11 [==============================] - 32s 3s/step - loss: 2.8310e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9844
# Epoch 65/200
# 11/11 [==============================] - 56s 5s/step - loss: 0.0502 - accuracy: 0.9886 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 66/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0260 - accuracy: 0.9941 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 67/200
# 11/11 [==============================] - 54s 5s/step - loss: 0.1150 - accuracy: 0.9882 - val_loss: 2.7969e-04 - val_accuracy: 1.0000
# Epoch 68/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0430 - accuracy: 0.9941 - val_loss: 1.6764e-08 - val_accuracy: 1.0000
# Epoch 69/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0149 - accuracy: 0.9971 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 70/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1362e-07 - val_accuracy: 1.0000
# Epoch 71/200
# 11/11 [==============================] - 34s 3s/step - loss: 1.4071e-06 - accuracy: 1.0000 - val_loss: 6.7813e-04 - val_accuracy: 1.0000
# Epoch 72/200
# 11/11 [==============================] - 34s 3s/step - loss: 7.2911e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 73/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1039 - accuracy: 0.9882 - val_loss: 2.3877e-06 - val_accuracy: 1.0000
# Epoch 74/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1453 - accuracy: 0.9765 - val_loss: 0.0930 - val_accuracy: 0.9688
# Epoch 75/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0767 - accuracy: 0.9853 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 76/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1796 - accuracy: 0.9853 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 77/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0218 - accuracy: 0.9971 - val_loss: 0.3681 - val_accuracy: 0.9375
# Epoch 78/200
# 11/11 [==============================] - 48s 5s/step - loss: 0.0273 - accuracy: 0.9943 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 79/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0623 - accuracy: 0.9912 - val_loss: 3.4943e-05 - val_accuracy: 1.0000
# Epoch 80/200
# 11/11 [==============================] - 45s 4s/step - loss: 0.1247 - accuracy: 0.9882 - val_loss: 5.1419e-06 - val_accuracy: 1.0000
# Epoch 81/200
# 11/11 [==============================] - 33s 3s/step - loss: 5.6924e-06 - accuracy: 1.0000 - val_loss: 9.5927e-06 - val_accuracy: 1.0000
# Epoch 82/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0143 - accuracy: 0.9971 - val_loss: 5.0291e-08 - val_accuracy: 1.0000
# Epoch 83/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0203 - accuracy: 0.9971 - val_loss: 2.0116e-07 - val_accuracy: 1.0000
# Epoch 84/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0411 - accuracy: 0.9941 - val_loss: 1.1176e-08 - val_accuracy: 1.0000
# Epoch 85/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0232 - accuracy: 0.9886 - val_loss: 0.3918 - val_accuracy: 0.9375
# Epoch 86/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1082 - accuracy: 0.9912 - val_loss: 0.3328 - val_accuracy: 0.9375
# Epoch 87/200
# 11/11 [==============================] - 39s 4s/step - loss: 0.0729 - accuracy: 0.9915 - val_loss: 3.7253e-09 - val_accuracy: 1.0000
# Epoch 88/200
# 11/11 [==============================] - 59s 5s/step - loss: 3.7086e-04 - accuracy: 1.0000 - val_loss: 0.4823 - val_accuracy: 0.9375
# Epoch 89/200
# 11/11 [==============================] - 61s 6s/step - loss: 0.0388 - accuracy: 0.9972 - val_loss: 6.8917e-07 - val_accuracy: 1.0000
# Epoch 90/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.1086 - accuracy: 0.9912 - val_loss: 1.3677 - val_accuracy: 0.8125
# Epoch 91/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0412 - accuracy: 0.9941 - val_loss: 0.4185 - val_accuracy: 0.9219
# Epoch 92/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0698 - accuracy: 0.9941 - val_loss: 0.0260 - val_accuracy: 0.9844
# Epoch 93/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0459 - accuracy: 0.9941 - val_loss: 1.2636 - val_accuracy: 0.8750
# Epoch 94/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.2277 - accuracy: 0.9941 - val_loss: 1.0150 - val_accuracy: 0.8594
# Epoch 95/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0693 - accuracy: 0.9882 - val_loss: 1.8612 - val_accuracy: 0.8594
# Epoch 96/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.1263 - accuracy: 0.9971 - val_loss: 0.5871 - val_accuracy: 0.9219
# Epoch 97/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0713 - accuracy: 0.9941 - val_loss: 2.3076 - val_accuracy: 0.8438
# Epoch 98/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.2131 - accuracy: 0.9882 - val_loss: 2.4214e-08 - val_accuracy: 1.0000
# Epoch 99/200
# 11/11 [==============================] - 42s 4s/step - loss: 0.0602 - accuracy: 0.9941 - val_loss: 2.5326e-04 - val_accuracy: 1.0000
# Epoch 100/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0295 - accuracy: 0.9971 - val_loss: 1.7881e-07 - val_accuracy: 1.0000
# Epoch 101/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 102/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 103/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 4.2841e-08 - val_accuracy: 1.0000
# Epoch 104/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.2643e-08 - val_accuracy: 1.0000
# Epoch 105/200
# 11/11 [==============================] - 33s 3s/step - loss: 5.4919e-05 - accuracy: 1.0000 - val_loss: 5.5879e-08 - val_accuracy: 1.0000
# Epoch 106/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 3.5390e-08 - val_accuracy: 1.0000
# Epoch 107/200
# 11/11 [==============================] - 56s 5s/step - loss: 3.5062e-10 - accuracy: 1.0000 - val_loss: 3.1665e-08 - val_accuracy: 1.0000
# Epoch 108/200
# 11/11 [==============================] - 35s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 109/200
# 11/11 [==============================] - 33s 3s/step - loss: 2.5383e-07 - accuracy: 1.0000 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 110/200
# 11/11 [==============================] - 33s 3s/step - loss: 1.7531e-09 - accuracy: 1.0000 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 111/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0376 - accuracy: 0.9971 - val_loss: 1.5793 - val_accuracy: 0.8438
# Epoch 112/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0984 - accuracy: 0.9886 - val_loss: 0.5501 - val_accuracy: 0.9219
# Epoch 113/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.2195 - accuracy: 0.9824 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 114/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1359 - accuracy: 0.9882 - val_loss: 8.3819e-08 - val_accuracy: 1.0000
# Epoch 115/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0642 - accuracy: 0.9882 - val_loss: 0.7504 - val_accuracy: 0.9219
# Epoch 116/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0317 - accuracy: 0.9941 - val_loss: 2.4214e-08 - val_accuracy: 1.0000
# Epoch 117/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1439 - accuracy: 0.9971 - val_loss: 0.0280 - val_accuracy: 0.9844
# Epoch 118/200
# 11/11 [==============================] - 32s 3s/step - loss: 6.2859e-07 - accuracy: 1.0000 - val_loss: 0.5917 - val_accuracy: 0.9219
# Epoch 119/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0681 - accuracy: 0.9971 - val_loss: 0.1453 - val_accuracy: 0.9844
# Epoch 120/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0824 - accuracy: 0.9971 - val_loss: 0.1727 - val_accuracy: 0.9688
# Epoch 121/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0027 - accuracy: 0.9971 - val_loss: 5.5879e-09 - val_accuracy: 1.0000
# Epoch 122/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 123/200
# 11/11 [==============================] - 31s 3s/step - loss: 9.8051e-07 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9844
# Epoch 124/200
# 11/11 [==============================] - 33s 3s/step - loss: 9.4571e-05 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9844
# Epoch 125/200
# 11/11 [==============================] - 32s 3s/step - loss: 1.7531e-09 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9844
# Epoch 126/200
# 11/11 [==============================] - 32s 3s/step - loss: 3.6473e-06 - accuracy: 1.0000 - val_loss: 0.0302 - val_accuracy: 0.9844
# Epoch 127/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.9276e-07 - val_accuracy: 1.0000
# Epoch 128/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0836 - accuracy: 0.9941 - val_loss: 0.0463 - val_accuracy: 0.9844
# Epoch 129/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.1250 - accuracy: 0.9882 - val_loss: 4.1468e-05 - val_accuracy: 1.0000
# Epoch 130/200
# 11/11 [==============================] - 49s 5s/step - loss: 0.0611 - accuracy: 0.9941 - val_loss: 0.1684 - val_accuracy: 0.9375
# Epoch 131/200
# 11/11 [==============================] - 46s 4s/step - loss: 3.3866e-10 - accuracy: 1.0000 - val_loss: 1.8626e-09 - val_accuracy: 1.0000
# Epoch 132/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.7676e-06 - val_accuracy: 1.0000
# Epoch 133/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0135 - accuracy: 0.9972 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 134/200
# 11/11 [==============================] - 32s 3s/step - loss: 2.0042e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 135/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 1.8626e-08 - val_accuracy: 1.0000
# Epoch 136/200
# 11/11 [==============================] - 32s 3s/step - loss: 4.9086e-09 - accuracy: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9375
# Epoch 137/200
# 11/11 [==============================] - 32s 3s/step - loss: 1.2375e-05 - accuracy: 1.0000 - val_loss: 0.7933 - val_accuracy: 0.9219
# Epoch 138/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 2.8768e-05 - val_accuracy: 1.0000
# Epoch 139/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0024 - accuracy: 0.9971 - val_loss: 0.1861 - val_accuracy: 0.9688
# Epoch 140/200
# 11/11 [==============================] - 32s 3s/step - loss: 1.0203e-07 - accuracy: 1.0000 - val_loss: 1.7462e-05 - val_accuracy: 1.0000
# Epoch 141/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.0780e-08 - val_accuracy: 1.0000
# Epoch 142/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.3039e-08 - val_accuracy: 1.0000
# Epoch 143/200
# 11/11 [==============================] - 31s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 144/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 5.5879e-09 - val_accuracy: 1.0000
# Epoch 145/200
# 11/11 [==============================] - 38s 3s/step - loss: 1.2790e-05 - accuracy: 1.0000 - val_loss: 5.5879e-09 - val_accuracy: 1.0000
# Epoch 146/200
# 11/11 [==============================] - 60s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 147/200
# 11/11 [==============================] - 54s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 148/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 149/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 150/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 151/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 152/200
# 11/11 [==============================] - 34s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 153/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 154/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 155/200
# 11/11 [==============================] - 54s 5s/step - loss: 1.8178e-05 - accuracy: 1.0000 - val_loss: 7.4506e-09 - val_accuracy: 1.0000
# Epoch 156/200
# 11/11 [==============================] - 59s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1176e-08 - val_accuracy: 1.0000
# Epoch 157/200
# 11/11 [==============================] - 36s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1176e-08 - val_accuracy: 1.0000
# Epoch 158/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 1.1176e-08 - val_accuracy: 1.0000
# Epoch 159/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0336 - accuracy: 0.9971 - val_loss: 1.5651 - val_accuracy: 0.9062
# Epoch 160/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0727 - accuracy: 0.9941 - val_loss: 0.9592 - val_accuracy: 0.9219
# Epoch 161/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0371 - accuracy: 0.9941 - val_loss: 2.4421 - val_accuracy: 0.8906
# Epoch 162/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1091 - accuracy: 0.9971 - val_loss: 3.0514 - val_accuracy: 0.8438
# Epoch 163/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1257 - accuracy: 0.9912 - val_loss: 1.8046 - val_accuracy: 0.8750
# Epoch 164/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0541 - accuracy: 0.9941 - val_loss: 0.7441 - val_accuracy: 0.9219
# Epoch 165/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0225 - accuracy: 0.9941 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 166/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1359 - accuracy: 0.9972 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 167/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0411 - accuracy: 0.9971 - val_loss: 9.3132e-09 - val_accuracy: 1.0000
# Epoch 168/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0433 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 169/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 3.6913e-06 - val_accuracy: 1.0000
# Epoch 170/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0587 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 171/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1077 - accuracy: 0.9886 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 172/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.1496 - accuracy: 0.9853 - val_loss: 9.3132e-09 - val_accuracy: 1.0000
# Epoch 173/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0203 - accuracy: 0.9971 - val_loss: 1.2271e-04 - val_accuracy: 1.0000
# Epoch 174/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0550 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 175/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0802 - accuracy: 0.9912 - val_loss: 3.1292e-07 - val_accuracy: 1.0000
# Epoch 176/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.3849 - accuracy: 0.9853 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 177/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0572 - accuracy: 0.9971 - val_loss: 0.3797 - val_accuracy: 0.9375
# Epoch 178/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.3430 - accuracy: 0.9912 - val_loss: 0.3466 - val_accuracy: 0.9531
# Epoch 179/200
# 11/11 [==============================] - 33s 3s/step - loss: 7.5551e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 180/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 1.1921e-07 - val_accuracy: 1.0000
# Epoch 181/200
# 11/11 [==============================] - 32s 3s/step - loss: 2.2657e-04 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9844
# Epoch 182/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.1087 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 183/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0266 - accuracy: 0.9971 - val_loss: 0.4859 - val_accuracy: 0.9531
# Epoch 184/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0201 - accuracy: 0.9972 - val_loss: 1.2864e-05 - val_accuracy: 1.0000
# Epoch 185/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0333 - accuracy: 0.9971 - val_loss: 0.1289 - val_accuracy: 0.9844
# Epoch 186/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0486 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 187/200
# 11/11 [==============================] - 32s 3s/step - loss: 6.9322e-04 - accuracy: 1.0000 - val_loss: 5.5769e-04 - val_accuracy: 1.0000
# Epoch 188/200
# 11/11 [==============================] - 32s 3s/step - loss: 8.9532e-05 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9844
# Epoch 189/200
# 11/11 [==============================] - 32s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 190/200
# 11/11 [==============================] - 57s 5s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 191/200
# 11/11 [==============================] - 37s 3s/step - loss: 3.1556e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 192/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 193/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 194/200
# 11/11 [==============================] - 33s 3s/step - loss: 9.4196e-07 - accuracy: 1.0000 - val_loss: 4.8099e-04 - val_accuracy: 1.0000
# Epoch 195/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0257 - accuracy: 0.9971 - val_loss: 7.3386e-07 - val_accuracy: 1.0000
# Epoch 196/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0050 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 197/200
# 11/11 [==============================] - 33s 3s/step - loss: 0.0559 - accuracy: 0.9971 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 198/200
# 11/11 [==============================] - 48s 5s/step - loss: 0.0432 - accuracy: 0.9971 - val_loss: 0.5363 - val_accuracy: 0.9688
# Epoch 199/200
# 11/11 [==============================] - 59s 5s/step - loss: 1.4025e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 200/200
# 11/11 [==============================] - 43s 4s/step - loss: 0.0249 - accuracy: 0.9941 - val_loss: 0.0408 - val_accuracy: 0.9844
